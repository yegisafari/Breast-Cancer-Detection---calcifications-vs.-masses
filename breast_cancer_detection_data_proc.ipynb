# %% [markdown]
# <a href="https://colab.research.google.com/github/yegisafari/Breast-Cancer-Detection---calcifications-vs.-masses/blob/main/breast_cancer_detection_data_proc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -r -N -c -np --user yeganehsafari --ask-password https://physionet.org/files/vindr-mammo/1.0.0/
# Out:
# Password for user ‘yeganehsafari’:
# --2024-06-28 08:15:19--  https://physionet.org/files/vindr-mammo/1.0.0/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="PhysioNet", charset="UTF-8"
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/index.html’
#
# physionet.org/files     [ <=>                ]     954  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-06-28 08:15:19 (181 MB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/index.html’ saved [954]
#
# Loading robots.txt; please ignore errors.
# --2024-06-28 08:15:19--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22 [text/plain]
# Saving to: ‘physionet.org/robots.txt’
#
# physionet.org/robot 100%[===================>]      22  --.-KB/s    in 0s
#
# 2024-06-28 08:15:19 (7.58 MB/s) - ‘physionet.org/robots.txt’ saved [22/22]
#
# --2024-06-28 08:15:19--  https://physionet.org/files/vindr-mammo/1.0.0/images/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/images/index.html’
#
# physionet.org/files     [       <=>          ] 674.07K   422KB/s    in 1.6s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-06-28 08:15:21 (422 KB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/images/index.html’ saved [690243]
#
# --2024-06-28 08:15:22--  https://physionet.org/files/vindr-mammo/1.0.0/LICENSE.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2348 (2.3K) [text/plain]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/LICENSE.txt’
#
# physionet.org/files 100%[===================>]   2.29K  --.-KB/s    in 0s
#
# 2024-06-28 08:15:22 (1.46 GB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/LICENSE.txt’ saved [2348/2348]
#
# --2024-06-28 08:15:22--  https://physionet.org/files/vindr-mammo/1.0.0/SHA256SUMS.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2880338 (2.7M) [text/plain]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/SHA256SUMS.txt’
#
# physionet.org/files 100%[===================>]   2.75M   500KB/s    in 5.7s
#
# 2024-06-28 08:15:28 (493 KB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/SHA256SUMS.txt’ saved [2880338/2880338]
#
# --2024-06-28 08:15:28--  https://physionet.org/files/vindr-mammo/1.0.0/breast-level_annotations.csv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2854100 (2.7M) [text/plain]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/breast-level_annotations.csv’
#
# physionet.org/files 100%[===================>]   2.72M   493KB/s    in 5.6s
#
# 2024-06-28 08:15:33 (497 KB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/breast-level_annotations.csv’ saved [2854100/2854100]
#
# --2024-06-28 08:15:33--  https://physionet.org/files/vindr-mammo/1.0.0/finding_annotations.csv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3495811 (3.3M) [text/plain]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/finding_annotations.csv’
#
# physionet.org/files 100%[===================>]   3.33M   506KB/s    in 7.0s
#
# 2024-06-28 08:15:40 (491 KB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/finding_annotations.csv’ saved [3495811/3495811]
#
# --2024-06-28 08:15:40--  https://physionet.org/files/vindr-mammo/1.0.0/metadata.csv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4360150 (4.2M) [text/plain]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/metadata.csv’
#
# physionet.org/files 100%[===================>]   4.16M   526KB/s    in 8.1s
#
# 2024-06-28 08:15:49 (526 KB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/metadata.csv’ saved [4360150/4360150]
#
# --2024-06-28 08:15:49--  https://physionet.org/files/vindr-mammo/1.0.0/images/0025a5dc99fd5c742026f0b2b030d3e9/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/images/0025a5dc99fd5c742026f0b2b030d3e9/index.html’
#
# physionet.org/files     [ <=>                ]     881  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-06-28 08:15:49 (174 MB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/images/0025a5dc99fd5c742026f0b2b030d3e9/index.html’ saved [881]
#
# --2024-06-28 08:15:49--  https://physionet.org/files/vindr-mammo/1.0.0/images/0028fb2c7f0b3a5cb9a80cb0e1cdbb91/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/images/0028fb2c7f0b3a5cb9a80cb0e1cdbb91/index.html’
#
# physionet.org/files     [ <=>                ]     881  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-06-28 08:15:49 (246 MB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/images/0028fb2c7f0b3a5cb9a80cb0e1cdbb91/index.html’ saved [881]
#
# --2024-06-28 08:15:49--  https://physionet.org/files/vindr-mammo/1.0.0/images/0034765af074f93ed33d5e8399355caf/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/images/0034765af074f93ed33d5e8399355caf/index.html’
#
# physionet.org/files     [ <=>                ]     881  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-06-28 08:15:49 (170 MB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/images/0034765af074f93ed33d5e8399355caf/index.html’ saved [881]
#
# --2024-06-28 08:15:49--  https://physionet.org/files/vindr-mammo/1.0.0/images/003700f3c960e0b9bca2b8437c3dbf05/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/images/003700f3c960e0b9bca2b8437c3dbf05/index.html’
#
# physionet.org/files     [ <=>                ]     881  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-06-28 08:15:49 (198 MB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/images/003700f3c960e0b9bca2b8437c3dbf05/index.html’ saved [881]
#
# --2024-06-28 08:15:49--  https://physionet.org/files/vindr-mammo/1.0.0/images/004426a40da27ef22a866538b772ac44/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/images/004426a40da27ef22a866538b772ac44/index.html’
#
# physionet.org/files     [ <=>                ]     881  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-06-28 08:15:49 (142 MB/s) - ‘physionet.org/files/vindr-mammo/1.0.0/images/004426a40da27ef22a866538b772ac44/index.html’ saved [881]
#
# --2024-06-28 08:15:49--  https://physionet.org/files/vindr-mammo/1.0.0/images/00464e1a9bfd88d33466321e03a55c1a/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/vindr-mammo/1.0.0/images/00464e1a9bfd88d33466321e03a55c1a/index.html’
#
# physionet.org/files     [ <=>                ]     881  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-06-28 08:15:49 
# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/physionet.org /content/drive/MyDrive/VinDr
# Out:
# cp: cannot stat '/content/physionet.org': No such file or directory

# %%
import os

# %%
main_path = '/content/drive/MyDrive/VinDr/files/vindr-mammo/1.0.0/images/'

# %%
import shutil
for folder in os.listdir(main_path):
  folder_path = os.path.join(main_path,folder)
  # print(os.listdir(folder_path))
  try:
    if len(os.listdir(folder_path)) > 1:
      print(os.listdir(folder_path))
    else:

      print(folder_path)
      shutil.rmtree(folder_path)
  except:
    pass
# Out:
# ['index.html', '2ddfad7286c2b016931ceccd1e2c7bbc.dicom', '451562831387e2822923204cf8f0873e.dicom', '47c8858666bcce92bcbd57974b5ce522.dicom', 'fcf12c2803ba8dc564bf1287c0c97d9a.dicom']
# ['index.html', '16e58fc1d65fa7587247e6224ee96527.dicom', '3704f91985dcbc69f6ac2803523d1ecb.dicom', '7fc1f1bb8bb1a7efaf7104e49c4d8b86.dicom', 'c4ce68631bf70949570ded31a3c69e60.dicom']
# ['index.html', '2aca993b3b6e2a32dddd170b00fd5e7d.dicom', '68f09c18925a66ef2840d4a62f237b31.dicom', 'b664cf1e7c968896144a3a2005cd3eb4.dicom', 'd39964544666ed08df9aa1e9e18d1262.dicom']
# ['index.html', '17c3d032d611eb3d1baf3434d62483a1.dicom', '3944b33b99c98e763763b9da54b4f41c.dicom', '51b47f9024ccad1356354f56ac916f29.dicom', '552a67df6d68b8f9498db7cadd23b0e0.dicom']
# ['index.html', '265596e3534efced063b4e656b7bd64f.dicom', '7197f7e6f5ca3b9821d0460dcdc975d3.dicom', '78b8a2f4b10790d6b2a11e081eaf209a.dicom', 'd3ae4a0aa59a608a2823c029e988985f.dicom']
# ['index.html', '1ae7d3012efee08737b9036e20649630.dicom', '643e9d162da220e8dbad171600375576.dicom', '97191e6e909300638a2a40c63f53a1d3.dicom', 'e7ad5afd2fb520aca0409c734315e385.dicom']
# ['index.html', '20ff52d0631b27a5387abcd5920b3e5d.dicom', '24c8e38d17b5d767df6670d1b2ce66f5.dicom', '8bbd63e7de0f6e7c5ab0b6f3db2abb26.dicom', '8fbe4dea1272837bade6b99711f25451.dicom']
# ['index.html', '31d6582c2181ae91fc2369c5b20af417.dicom', '669855e0fcbf069c4de85d4586ad8e26.dicom', '8e22baa49decc916308b6b89191a49cb.dicom', '9c67560e601fe9ae14381396bf9a787a.dicom']
# ['index.html', '14bffe41f224fce0afdd90c35c0abacb.dicom', '2098cb1050e7165044544d77bb8bfd4a.dicom', '6e5117c49a83c06b3c8ccf26bbab657b.dicom', '70344c1fc8ac0185eabb0f793dda3a40.dicom']
# ['index.html', '63d3f4fe3f265d310a1023bcf8336a49.dicom', 'b25443ab817d5590d25b733c1e59192d.dicom', 'e13c80239d7714e3d964b5f3e37bcff6.dicom', 'f1f79501410a98782c0a03b48e66df83.dicom']
# ['index.html', '01d524575ad7f3be2080305dc1dedc07.dicom', '2bb372e5885a059f6633f013b645814e.dicom', '3f7902ae65b8a5873af88994cd581048.dicom', 'f3c400ef93ef644d8c83fbe2f6431f7a.dicom']
# ['index.html', '2feab51140b38f9ec90e17b7006501b2.dicom', 'b70e49d5e28ad1ac33920a9b641c7b8f.dicom', 'e851ee79457fd5251b630a54ec061cad.dicom', 'f3cbed97f4bb7897467e1e8bab45966e.dicom']
# ['index.html', '202d1c29785f6327985ffda7100e2265.dicom', '7adeb584564fc161d897a3fc719acd17.dicom', 'edb7f6e44809405ec40a9c2537da62e6.dicom', 'f6c7f3c3e03d612002800f20b1282309.dicom']
# ['index.html', '7472fefcaba6333dca144e9196690adc.dicom', '8cf51fb132f323fc9e77bd0fcf56f884.dicom', 'da276f01f19f316503454f86dfff2fad.dicom', 'ead31c71e819823fd073492995e4fc1f.dicom']
# ['index.html', '2e65f00c5735903fa619ac0f9084ceff.dicom', 'a5920fd9fcc7b53652a5aee37f606211.dicom', 'ca15d95c3d57cfc4f0ed096151cc7e27.dicom', 'cdcca24b57291ec433082a4423efc88b.dicom']
# ['index.html', '44b20cab46f81d4836d7bcdfba9f5125.dicom', 'a3abc78b80b104b171f2dd76c215f1a5.dicom', 'b01b8a03a187dca67e4b1d5c64a77e5a.dicom', 'e82b6324ff951df4158627cf430996b7.dicom']
# ['index.html', '54ba7453b15e6f8741559e4da4995c5d.dicom', '73bbf7f4b61b802f1c27af731bf7dc64.dicom', '8bfa19ee1c0269107ebdc7b31c7bfc98.dicom', 'e18732b78c14fdb07ce24c85977c0291.dicom']
# ['index.html', '7b956df1434ed7921b9e377ecdbf60d0.dicom', '8083259693e90847d21e137516155bab.dicom', '83d89dde5243c74fc0e129d1952f1d68.dicom', 'dcc451349cd225bf8031533b185aecac.dicom']
# ['index.html', '44c7f09624f93d9b787946e290122fac.dicom', '85462e42189a62be66982e281121b46e.dicom', '8e6f22c0c3bd290b61ee69b785f915e8.dicom', 'c3d32dc36523668c3ae06888ec89a300.dicom']
# ['index.html', '17c748761a527f6a5a69137a9d6968c1.dicom']

# %%
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-2.4.4-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.4 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.4.4

# %%
import os
import ast
import pandas as pd
import numpy as np
import seaborn as sns
from tqdm import tqdm
from pydicom import dcmread
from skimage.io import imsave
from skimage.transform import resize

# %%
data_dir =  '/content/drive/MyDrive/VinDr/files/vindr-mammo/1.0.0/'
data = pd.read_csv(os.path.join(data_dir,'breast-level_annotations.csv'))
meta = pd.read_csv(os.path.join(data_dir,'metadata.csv'))
meta = meta.rename(columns={'SOP Instance UID': 'image_id'})
data = data.merge(meta, on='image_id')

# %%
data['breast_birads'].value_counts(normalize=False)
# Out:
# breast_birads
# BI-RADS 1    13406
# BI-RADS 2     4676
# BI-RADS 3      930
# BI-RADS 4      762
# BI-RADS 5      226
# Name: count, dtype: int64

# %%
data['breast_birads'].value_counts(normalize=True)
# Out:
# breast_birads
# BI-RADS 1    0.6703
# BI-RADS 2    0.2338
# BI-RADS 3    0.0465
# BI-RADS 4    0.0381
# BI-RADS 5    0.0113
# Name: proportion, dtype: float64

# %%
data["Manufacturer"].value_counts(normalize=False)
# Out:
# Manufacturer
# SIEMENS              15244
# Planmed               3796
# IMS s.r.l.             736
# IMS GIOTTO S.p.A.      224
# Name: count, dtype: int64

# %%
data["Manufacturer"].value_counts(normalize=True)
# Out:
# Manufacturer
# SIEMENS              0.7622
# Planmed              0.1898
# IMS s.r.l.           0.0368
# IMS GIOTTO S.p.A.    0.0112
# Name: proportion, dtype: float64

# %%
data["Manufacturer's Model Name"].value_counts(normalize=False)
# Out:
# Manufacturer's Model Name
# Mammomat Inspiration    15244
# Planmed Nuance           3796
# GIOTTO CLASS              628
# GIOTTO IMAGE 3DL          332
# Name: count, dtype: int64

# %%
data["Manufacturer's Model Name"].value_counts(normalize=True)
# Out:
# Manufacturer's Model Name
# Mammomat Inspiration    0.7622
# Planmed Nuance          0.1898
# GIOTTO CLASS            0.0314
# GIOTTO IMAGE 3DL        0.0166
# Name: proportion, dtype: float64

# %%
sns.catplot(x='breast_birads', data=data, order=['BI-RADS 1', 'BI-RADS 2', 'BI-RADS 3', 'BI-RADS 4', 'BI-RADS 5'], kind='count')

# %%
sns.catplot(x='breast_density', order=['DENSITY A', 'DENSITY B', 'DENSITY C', 'DENSITY D'], data=data, kind='count')

# %%
image_size = (512,512)

# %%
image_folder = os.path.join(data_dir,'images')
data2 = data[data['study_id'].apply(lambda x : x in os.listdir(image_folder) )]

# %%
preproc_dir = 'images_512x512'
out_dir = os.path.join(data_dir,preproc_dir)

if not os.path.exists(out_dir):
    os.makedirs(out_dir)
image_folder = os.path.join(data_dir,'images')



for study_id  in os.listdir(image_folder) :
  if not study_id == 'index.html':
    out_path = os.path.join(out_dir,study_id)
    if not os.path.exists(out_path):
          os.makedirs(out_path)

    for image_id in os.listdir(os.path.join(image_folder,study_id)):


      image_id = image_id.split('.')[0]
      img_path = os.path.join(data_dir, 'images', study_id, image_id + '.dicom')
      out_fn = os.path.join(out_path, image_id + '.png')

      if not os.path.exists(out_fn) and not image_id =='index':
          try:
            dicom = dcmread(img_path)
            image = dicom.pixel_array
            idx = data[data['image_id']==image_id].index[0]

            window = np.array(ast.literal_eval(data.loc[idx, 'Window Width']))
            level = np.array(ast.literal_eval(data.loc[idx, 'Window Center']))

            # Multiple window/level settings for IMS Giotto images
            if data.loc[idx, "Manufacturer's Model Name"] == 'GIOTTO IMAGE 3DL' or data.loc[idx, "Manufacturer's Model Name"] == 'GIOTTO CLASS':
                window = window[0]
                level = level[0]

            # MONOCHROME1 images need special handling for inverting pixel intensities
            if data.loc[idx, 'Photometric Interpretation'] == 'MONOCHROME1':
                image[image==1] += data.loc[idx, 'Pixel Padding Value']
                level = np.max(image) - level
                image = np.max(image) - image

            # Resize image
            image = resize(image, output_shape=image_size, preserve_range=True).astype(np.float32)

            # Normalize pixel intensities, and convert to 8-bit
            image -= (level - window/2)
            image /= window
            image[image<0] = 0
            image[image>1] = 1
            image *= 255

            # Flip image with laterality equals right
            if data.loc[idx, 'laterality'] == 'R':
                image = image[:, ::-1]

            # image.tofile(os.path.join(out_path, data.loc[idx, 'image_id'] + '.dat'))
            imsave(out_fn, image.astype(np.uint8))
          except:
            pass

# %%
data2 = data2.reset_index()

# %%
data2['split'] = 'training'

# %%
data2['split'].iloc[2*len(data2)//3:] = 'test'
# Out:
# <ipython-input-23-194dff421624>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['split'].iloc[2*len(data2)//3:] = 'test'

# %%
data2['split'].value_counts()
# Out:
# split
# training    88
# test        44
# Name: count, dtype: int64
